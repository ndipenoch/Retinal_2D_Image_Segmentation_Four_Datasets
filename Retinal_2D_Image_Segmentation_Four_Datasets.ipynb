# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install patchify
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.19.5)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
# !pip install imagecodecs
# Out:
# Collecting imagecodecs
#   Downloading imagecodecs-2021.8.26-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.6 MB)
#      |████████████████████████████████| 29.6 MB 71.0 MB/s
# Requirement already satisfied: numpy>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from imagecodecs) (1.19.5)
# Installing collected packages: imagecodecs
# Successfully installed imagecodecs-2021.8.26

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
from PIL import Image
import tifffile as tiff
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K
from tensorflow.keras import backend as K
from sklearn.metrics import jaccard_score,confusion_matrix

np.random.seed(0)

# %%
def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)
 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)
 
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)
  
def accuracy(y_true, y_pred):
    cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
    acc = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1])
    return acc
  
def IoU(y_true, y_pred, labels = [0, 1]):
   IoU = []
   for label in labels:
      jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
      IoU.append(jaccard)     
   return np.mean(IoU)

# %%
#convolutional block
def conv_block(x, kernelsize, filters, dropout, batchnorm=False): 
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(x)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(conv)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    return conv


#residual convolutional block
def res_conv_block(x, kernelsize, filters, dropout, batchnorm=False):
    conv1 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        conv1 = layers.BatchNormalization(axis=3)(conv1)
    conv1 = layers.Activation('relu')(conv1)    
    conv2 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(conv1)
    if batchnorm is True:
        conv2 = layers.BatchNormalization(axis=3)(conv2)
        conv2 = layers.Activation("relu")(conv2)
    if dropout > 0:
        conv2 = layers.Dropout(dropout)(conv2)
        
    #skip connection    
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)
    shortcut = layers.Activation("relu")(shortcut)
    respath = layers.add([shortcut, conv2])       
    return respath


#gating signal for attention unit
def gatingsignal(input, out_size, batchnorm=False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batchnorm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

# %% [markdown]
# <h3><center>U-NET Architecture</center></h3>

# %%
#Simple U-NET
def unetmodel(input_shape, dropout=0.2, batchnorm=True):    
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    

    # Downsampling layers
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers   
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, dn_4], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, dn_3], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
       
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, dn_2], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, dn_1], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)    
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    #model.summary()        
    return model

# %% [markdown]
# <h3><center>Train the Model</center></h3>

# %%
#CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized


path1 = 'drive/MyDrive/Datasets/STARE/Training/Images' #training images directory
path2 = 'drive/MyDrive/Datasets/STARE/Training/Labels' #training masks directory

image_dataset = []
mask_dataset = [] 
myList = [".jpg",".ppm","png","jpeg","JPG","gif","tif"]

patch_size = 512

images = sorted(os.listdir(path1)) 
for i, image_name in enumerate(images): 
   if image_name.endswith(tuple(myList)): 
       #image = tiff.imread(path1+"/"+image_name)
       image = skimage.io.imread(path1+"/"+image_name)  #Read image
       image = image[:,:,1] #selecting green channel
       image = clahe_equalized(image) #applying CLAHE
       SIZE_X = (image.shape[1]//patch_size)*patch_size #getting size multiple of patch size
       SIZE_Y = (image.shape[0]//patch_size)*patch_size #getting size multiple of patch size
       image = Image.fromarray(image)        
       image = image.resize((SIZE_X, SIZE_Y)) #resize image       
       image = np.array(image) 
       patches_img = patchify(image, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
       for i in range(patches_img.shape[0]):
           for j in range(patches_img.shape[1]):                        
               single_patch_img = patches_img[i,j,:,:]                 
               single_patch_img = (single_patch_img.astype('float32')) / 255.
               image_dataset.append(single_patch_img)

masks = sorted(os.listdir(path2)) 
for i, mask_name in enumerate(masks):  
    if mask_name.endswith(tuple(myList)):                  
        mask = skimage.io.imread(path2+"/"+mask_name)   #Read masks
        SIZE_X = (mask.shape[1]//patch_size)*patch_size #getting size multiple of patch size
        SIZE_Y = (mask.shape[0]//patch_size)*patch_size #getting size multiple of patch size
        mask = Image.fromarray(mask)        
        mask = mask.resize((SIZE_X, SIZE_Y))  #resize image
        mask = np.array(mask)
        patches_mask = patchify(mask, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
        for i in range(patches_mask.shape[0]):
            for j in range(patches_mask.shape[1]):                            
                single_patch_mask = patches_mask[i,j,:,:]
                single_patch_mask = (single_patch_mask.astype('float32'))/255. 
                mask_dataset.append(single_patch_mask) 
 
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)
image_dataset = np.expand_dims(image_dataset,axis=-1)
mask_dataset =  np.expand_dims(mask_dataset,axis=-1)


#importing models
#from model import unetmodel, residualunet, attentionunet, attention_residualunet
from tensorflow.keras.optimizers import Adam
#from evaluation_metrics import IoU_coef,IoU_loss

IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

model = unetmodel(input_shape)
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])

#splitting data into 70-30 ratio to validate training performance
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size=0.3, random_state=0)

#train model
history = model.fit(x_train, y_train, 
                    verbose=1,
                    batch_size = 16,
                    validation_data=(x_test, y_test ), 
                    shuffle=False,
                    epochs=10000)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6724 - val_accuracy: 0.9345 - val_IoU_coef: 0.6724
# Epoch 7502/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6720 - val_accuracy: 0.9345 - val_IoU_coef: 0.6720
# Epoch 7503/10000
# 1/1 [==============================] - 0s 349ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6720 - val_accuracy: 0.9346 - val_IoU_coef: 0.6720
# Epoch 7504/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6725 - val_accuracy: 0.9346 - val_IoU_coef: 0.6725
# Epoch 7505/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6726 - val_accuracy: 0.9345 - val_IoU_coef: 0.6726
# Epoch 7506/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6715 - val_accuracy: 0.9344 - val_IoU_coef: 0.6715
# Epoch 7507/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6699 - val_accuracy: 0.9343 - val_IoU_coef: 0.6699
# Epoch 7508/10000
# 1/1 [==============================] - 0s 350ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6701 - val_accuracy: 0.9343 - val_IoU_coef: 0.6701
# Epoch 7509/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6708 - val_accuracy: 0.9342 - val_IoU_coef: 0.6708
# Epoch 7510/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6707 - val_accuracy: 0.9341 - val_IoU_coef: 0.6707
# Epoch 7511/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6705 - val_accuracy: 0.9341 - val_IoU_coef: 0.6705
# Epoch 7512/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6705 - val_accuracy: 0.9341 - val_IoU_coef: 0.6705
# Epoch 7513/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6707 - val_accuracy: 0.9340 - val_IoU_coef: 0.6707
# Epoch 7514/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6711 - val_accuracy: 0.9340 - val_IoU_coef: 0.6711
# Epoch 7515/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6716 - val_accuracy: 0.9340 - val_IoU_coef: 0.6716
# Epoch 7516/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6717 - val_accuracy: 0.9342 - val_IoU_coef: 0.6717
# Epoch 7517/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6729 - val_accuracy: 0.9343 - val_IoU_coef: 0.6729
# Epoch 7518/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6734 - val_accuracy: 0.9343 - val_IoU_coef: 0.6734
# Epoch 7519/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6739 - val_accuracy: 0.9343 - val_IoU_coef: 0.6739
# Epoch 7520/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6742 - val_accuracy: 0.9345 - val_IoU_coef: 0.6742
# Epoch 7521/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6738 - val_accuracy: 0.9345 - val_IoU_coef: 0.6738
# Epoch 7522/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6739 - val_accuracy: 0.9344 - val_IoU_coef: 0.6739
# Epoch 7523/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6741 - val_accuracy: 0.9343 - val_IoU_coef: 0.6741
# Epoch 7524/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8299 - accuracy: 0.9402 - IoU_coef: 0.8299 - val_loss: -0.6744 - val_accuracy: 0.9344 - val_IoU_coef: 0.6744
# Epoch 7525/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6744 - val_accuracy: 0.9345 - val_IoU_coef: 0.6744
# Epoch 7526/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8298 - accuracy: 0.9402 - IoU_coef: 0.8298 - val_loss: -0.6746 - val_accuracy: 0.9344 - val_IoU_coef: 0.6746
# Epoch 7527/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6748 - val_accuracy: 0.9343 - val_IoU_coef: 0.6748
# Epoch 7528/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8298 - accuracy: 0.9402 - IoU_coef: 0.8298 - val_loss: -0.6756 - val_accuracy: 0.9345 - val_IoU_coef: 0.6756
# Epoch 7529/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6755 - val_accuracy: 0.9345 - val_IoU_coef: 0.6755
# Epoch 7530/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8299 - accuracy: 0.9402 - IoU_coef: 0.8299 - val_loss: -0.6748 - val_accuracy: 0.9344 - val_IoU_coef: 0.6748
# Epoch 7531/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6745 - val_accuracy: 0.9343 - val_IoU_coef: 0.6745
# Epoch 7532/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6755 - val_accuracy: 0.9344 - val_IoU_coef: 0.6755
# Epoch 7533/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6762 - val_accuracy: 0.9346 - val_IoU_coef: 0.6762
# Epoch 7534/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6769 - val_accuracy: 0.9347 - val_IoU_coef: 0.6769
# Epoch 7535/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6769 - val_accuracy: 0.9346 - val_IoU_coef: 0.6769
# Epoch 7536/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6763 - val_accuracy: 0.9346 - val_IoU_coef: 0.6763
# Epoch 7537/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6758 - val_accuracy: 0.9345 - val_IoU_coef: 0.6758
# Epoch 7538/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6763 - val_accuracy: 0.9346 - val_IoU_coef: 0.6763
# Epoch 7539/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6767 - val_accuracy: 0.9346 - val_IoU_coef: 0.6767
# Epoch 7540/10000
# 1/1 [==============================] - 0s 350ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6766 - val_accuracy: 0.9346 - val_IoU_coef: 0.6766
# Epoch 7541/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6758 - val_accuracy: 0.9346 - val_IoU_coef: 0.6758
# Epoch 7542/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8300 - accuracy: 0.9402 - IoU_coef: 0.8300 - val_loss: -0.6762 - val_accuracy: 0.9346 - val_IoU_coef: 0.6762
# Epoch 7543/10000
# 1/1 [==============================] - 0s 350ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6772 - val_accuracy: 0.9347 - val_IoU_coef: 0.6772
# Epoch 7544/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6775 - val_accuracy: 0.9347 - val_IoU_coef: 0.6775
# Epoch 7545/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8299 - accuracy: 0.9402 - IoU_coef: 0.8299 - val_loss: -0.6767 - val_accuracy: 0.9346 - val_IoU_coef: 0.6767
# Epoch 7546/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6751 - val_accuracy: 0.9345 - val_IoU_coef: 0.6751
# Epoch 7547/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6740 - val_accuracy: 0.9344 - val_IoU_coef: 0.6740
# Epoch 7548/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6748 - val_accuracy: 0.9344 - val_IoU_coef: 0.6748
# Epoch 7549/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6760 - val_accuracy: 0.9346 - val_IoU_coef: 0.6760
# Epoch 7550/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6763 - val_accuracy: 0.9347 - val_IoU_coef: 0.6763
# Epoch 7551/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6761 - val_accuracy: 0.9347 - val_IoU_coef: 0.6761
# Epoch 7552/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8302 - accuracy: 0.9402 - IoU_coef: 0.8302 - val_loss: -0.6761 - val_accuracy: 0.9347 - val_IoU_coef: 0.6761
# Epoch 7553/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6770 - val_accuracy: 0.9348 - val_IoU_coef: 0.6770
# Epoch 7554/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6771 - val_accuracy: 0.9348 - val_IoU_coef: 0.6771
# Epoch 7555/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6774 - val_accuracy: 0.9349 - val_IoU_coef: 0.6774
# Epoch 7556/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6775 - val_accuracy: 0.9349 - val_IoU_coef: 0.6775
# Epoch 7557/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6785 - val_accuracy: 0.9349 - val_IoU_coef: 0.6785
# Epoch 7558/10000
# 1/1 [==============================] - 0s 367ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6792 - val_accuracy: 0.9350 - val_IoU_coef: 0.6792
# Epoch 7559/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6788 - val_accuracy: 0.9350 - val_IoU_coef: 0.6788
# Epoch 7560/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6783 - val_accuracy: 0.9349 - val_IoU_coef: 0.6783
# Epoch 7561/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6776 - val_accuracy: 0.9348 - val_IoU_coef: 0.6776
# Epoch 7562/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6766 - val_accuracy: 0.9347 - val_IoU_coef: 0.6766
# Epoch 7563/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6755 - val_accuracy: 0.9346 - val_IoU_coef: 0.6755
# Epoch 7564/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6753 - val_accuracy: 0.9346 - val_IoU_coef: 0.6753
# Epoch 7565/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6751 - val_accuracy: 0.9345 - val_IoU_coef: 0.6751
# Epoch 7566/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6749 - val_accuracy: 0.9345 - val_IoU_coef: 0.6749
# Epoch 7567/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6750 - val_accuracy: 0.9345 - val_IoU_coef: 0.6750
# Epoch 7568/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6753 - val_accuracy: 0.9345 - val_IoU_coef: 0.6753
# Epoch 7569/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6756 - val_accuracy: 0.9346 - val_IoU_coef: 0.6756
# Epoch 7570/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6757 - val_accuracy: 0.9347 - val_IoU_coef: 0.6757
# Epoch 7571/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6755 - val_accuracy: 0.9347 - val_IoU_coef: 0.6755
# Epoch 7572/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6753 - val_accuracy: 0.9346 - val_IoU_coef: 0.6753
# Epoch 7573/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6753 - val_accuracy: 0.9346 - val_IoU_coef: 0.6753
# Epoch 7574/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6758 - val_accuracy: 0.9347 - val_IoU_coef: 0.6758
# Epoch 7575/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6761 - val_accuracy: 0.9348 - val_IoU_coef: 0.6761
# Epoch 7576/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6763 - val_accuracy: 0.9347 - val_IoU_coef: 0.6763
# Epoch 7577/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6760 - val_accuracy: 0.9346 - val_IoU_coef: 0.6760
# Epoch 7578/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6752 - val_accuracy: 0.9346 - val_IoU_coef: 0.6752
# Epoch 7579/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6756 - val_accuracy: 0.9346 - val_IoU_coef: 0.6756
# Epoch 7580/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6767 - val_accuracy: 0.9347 - val_IoU_coef: 0.6767
# Epoch 7581/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6770 - val_accuracy: 0.9346 - val_IoU_coef: 0.6770
# Epoch 7582/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6774 - val_accuracy: 0.9347 - val_IoU_coef: 0.6774
# Epoch 7583/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6781 - val_accuracy: 0.9348 - val_IoU_coef: 0.6781
# Epoch 7584/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6788 - val_accuracy: 0.9349 - val_IoU_coef: 0.6788
# Epoch 7585/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6790 - val_accuracy: 0.9348 - val_IoU_coef: 0.6790
# Epoch 7586/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6786 - val_accuracy: 0.9347 - val_IoU_coef: 0.6786
# Epoch 7587/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6778 - val_accuracy: 0.9346 - val_IoU_coef: 0.6778
# Epoch 7588/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6766 - val_accuracy: 0.9345 - val_IoU_coef: 0.6766
# Epoch 7589/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6763 - val_accuracy: 0.9345 - val_IoU_coef: 0.6763
# Epoch 7590/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6761 - val_accuracy: 0.9344 - val_IoU_coef: 0.6761
# Epoch 7591/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6754 - val_accuracy: 0.9343 - val_IoU_coef: 0.6754
# Epoch 7592/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6747 - val_accuracy: 0.9343 - val_IoU_coef: 0.6747
# Epoch 7593/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6742 - val_accuracy: 0.9343 - val_IoU_coef: 0.6742
# Epoch 7594/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6736 - val_accuracy: 0.9342 - val_IoU_coef: 0.6736
# Epoch 7595/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6729 - val_accuracy: 0.9341 - val_IoU_coef: 0.6729
# Epoch 7596/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6719 - val_accuracy: 0.9341 - val_IoU_coef: 0.6719
# Epoch 7597/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6714 - val_accuracy: 0.9340 - val_IoU_coef: 0.6714
# Epoch 7598/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6713 - val_accuracy: 0.9339 - val_IoU_coef: 0.6713
# Epoch 7599/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6726 - val_accuracy: 0.9339 - val_IoU_coef: 0.6726
# Epoch 7600/10000
# 1/1 [==============================] - 0s 337ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6737 - val_accuracy: 0.9341 - val_IoU_coef: 0.6737
# Epoch 7601/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6741 - val_accuracy: 0.9342 - val_IoU_coef: 0.6741
# Epoch 7602/10000
# 1/1 [==============================] - 0s 368ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6741 - val_accuracy: 0.9342 - val_IoU_coef: 0.6741
# Epoch 7603/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6736 - val_accuracy: 0.9341 - val_IoU_coef: 0.6736
# Epoch 7604/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6735 - val_accuracy: 0.9341 - val_IoU_coef: 0.6735
# Epoch 7605/10000
# 1/1 [==============================] - 0s 338ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6742 - val_accuracy: 0.9343 - val_IoU_coef: 0.6742
# Epoch 7606/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6750 - val_accuracy: 0.9344 - val_IoU_coef: 0.6750
# Epoch 7607/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6753 - val_accuracy: 0.9345 - val_IoU_coef: 0.6753
# Epoch 7608/10000
# 1/1 [==============================] - 0s 337ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6753 - val_accuracy: 0.9345 - val_IoU_coef: 0.6753
# Epoch 7609/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6753 - val_accuracy: 0.9346 - val_IoU_coef: 0.6753
# Epoch 7610/10000
# 1/1 [==============================] - 0s 365ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6749 - val_accuracy: 0.9347 - val_IoU_coef: 0.6749
# Epoch 7611/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6755 - val_accuracy: 0.9347 - val_IoU_coef: 0.6755
# Epoch 7612/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6757 - val_accuracy: 0.9346 - val_IoU_coef: 0.6757
# Epoch 7613/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6751 - val_accuracy: 0.9346 - val_IoU_coef: 0.6751
# Epoch 7614/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6747 - val_accuracy: 0.9345 - val_IoU_coef: 0.6747
# Epoch 7615/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6747 - val_accuracy: 0.9345 - val_IoU_coef: 0.6747
# Epoch 7616/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6752 - val_accuracy: 0.9344 - val_IoU_coef: 0.6752
# Epoch 7617/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6744 - val_accuracy: 0.9343 - val_IoU_coef: 0.6744
# Epoch 7618/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6741 - val_accuracy: 0.9343 - val_IoU_coef: 0.6741
# Epoch 7619/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6736 - val_accuracy: 0.9343 - val_IoU_coef: 0.6736
# Epoch 7620/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8301 - accuracy: 0.9402 - IoU_coef: 0.8301 - val_loss: -0.6744 - val_accuracy: 0.9343 - val_IoU_coef: 0.6744
# Epoch 7621/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6751 - val_accuracy: 0.9343 - val_IoU_coef: 0.6751
# Epoch 7622/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6745 - val_accuracy: 0.9342 - val_IoU_coef: 0.6745
# Epoch 7623/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6735 - val_accuracy: 0.9341 - val_IoU_coef: 0.6735
# Epoch 7624/10000
# 1/1 [==============================] - 0s 349ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6726 - val_accuracy: 0.9340 - val_IoU_coef: 0.6726
# Epoch 7625/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6729 - val_accuracy: 0.9340 - val_IoU_coef: 0.6729
# Epoch 7626/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6739 - val_accuracy: 0.9340 - val_IoU_coef: 0.6739
# Epoch 7627/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6736 - val_accuracy: 0.9339 - val_IoU_coef: 0.6736
# Epoch 7628/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6727 - val_accuracy: 0.9339 - val_IoU_coef: 0.6727
# Epoch 7629/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8305 - accuracy: 0.9402 - IoU_coef: 0.8305 - val_loss: -0.6721 - val_accuracy: 0.9338 - val_IoU_coef: 0.6721
# Epoch 7630/10000
# 1/1 [==============================] - 0s 349ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6722 - val_accuracy: 0.9338 - val_IoU_coef: 0.6722
# Epoch 7631/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6725 - val_accuracy: 0.9338 - val_IoU_coef: 0.6725
# Epoch 7632/10000
# 1/1 [==============================] - 0s 349ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6731 - val_accuracy: 0.9339 - val_IoU_coef: 0.6731
# Epoch 7633/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6730 - val_accuracy: 0.9339 - val_IoU_coef: 0.6730
# Epoch 7634/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6733 - val_accuracy: 0.9340 - val_IoU_coef: 0.6733
# Epoch 7635/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6737 - val_accuracy: 0.9340 - val_IoU_coef: 0.6737
# Epoch 7636/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6746 - val_accuracy: 0.9341 - val_IoU_coef: 0.6746
# Epoch 7637/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6746 - val_accuracy: 0.9342 - val_IoU_coef: 0.6746
# Epoch 7638/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6740 - val_accuracy: 0.9342 - val_IoU_coef: 0.6740
# Epoch 7639/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6735 - val_accuracy: 0.9341 - val_IoU_coef: 0.6735
# Epoch 7640/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6740 - val_accuracy: 0.9342 - val_IoU_coef: 0.6740
# Epoch 7641/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6741 - val_accuracy: 0.9342 - val_IoU_coef: 0.6741
# Epoch 7642/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6736 - val_accuracy: 0.9342 - val_IoU_coef: 0.6736
# Epoch 7643/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6728 - val_accuracy: 0.9341 - val_IoU_coef: 0.6728
# Epoch 7644/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6725 - val_accuracy: 0.9341 - val_IoU_coef: 0.6725
# Epoch 7645/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6728 - val_accuracy: 0.9341 - val_IoU_coef: 0.6728
# Epoch 7646/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6728 - val_accuracy: 0.9342 - val_IoU_coef: 0.6728
# Epoch 7647/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6730 - val_accuracy: 0.9342 - val_IoU_coef: 0.6730
# Epoch 7648/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6725 - val_accuracy: 0.9340 - val_IoU_coef: 0.6725
# Epoch 7649/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6730 - val_accuracy: 0.9341 - val_IoU_coef: 0.6730
# Epoch 7650/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6742 - val_accuracy: 0.9343 - val_IoU_coef: 0.6742
# Epoch 7651/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6752 - val_accuracy: 0.9344 - val_IoU_coef: 0.6752
# Epoch 7652/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6757 - val_accuracy: 0.9343 - val_IoU_coef: 0.6757
# Epoch 7653/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6751 - val_accuracy: 0.9343 - val_IoU_coef: 0.6751
# Epoch 7654/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6752 - val_accuracy: 0.9343 - val_IoU_coef: 0.6752
# Epoch 7655/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6756 - val_accuracy: 0.9344 - val_IoU_coef: 0.6756
# Epoch 7656/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6757 - val_accuracy: 0.9343 - val_IoU_coef: 0.6757
# Epoch 7657/10000
# 1/1 [==============================] - 0s 368ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6752 - val_accuracy: 0.9341 - val_IoU_coef: 0.6752
# Epoch 7658/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6736 - val_accuracy: 0.9339 - val_IoU_coef: 0.6736
# Epoch 7659/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6720 - val_accuracy: 0.9337 - val_IoU_coef: 0.6720
# Epoch 7660/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6703 - val_accuracy: 0.9335 - val_IoU_coef: 0.6703
# Epoch 7661/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6685 - val_accuracy: 0.9333 - val_IoU_coef: 0.6685
# Epoch 7662/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6674 - val_accuracy: 0.9332 - val_IoU_coef: 0.6674
# Epoch 7663/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6677 - val_accuracy: 0.9332 - val_IoU_coef: 0.6677
# Epoch 7664/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8307 - accuracy: 0.9402 - IoU_coef: 0.8307 - val_loss: -0.6682 - val_accuracy: 0.9333 - val_IoU_coef: 0.6682
# Epoch 7665/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6685 - val_accuracy: 0.9333 - val_IoU_coef: 0.6685
# Epoch 7666/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6692 - val_accuracy: 0.9334 - val_IoU_coef: 0.6692
# Epoch 7667/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6700 - val_accuracy: 0.9335 - val_IoU_coef: 0.6700
# Epoch 7668/10000
# 1/1 [==============================] - 0s 338ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6716 - val_accuracy: 0.9337 - val_IoU_coef: 0.6716
# Epoch 7669/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6734 - val_accuracy: 0.9339 - val_IoU_coef: 0.6734
# Epoch 7670/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6741 - val_accuracy: 0.9341 - val_IoU_coef: 0.6741
# Epoch 7671/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6747 - val_accuracy: 0.9342 - val_IoU_coef: 0.6747
# Epoch 7672/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6750 - val_accuracy: 0.9342 - val_IoU_coef: 0.6750
# Epoch 7673/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6748 - val_accuracy: 0.9342 - val_IoU_coef: 0.6748
# Epoch 7674/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6743 - val_accuracy: 0.9342 - val_IoU_coef: 0.6743
# Epoch 7675/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6735 - val_accuracy: 0.9342 - val_IoU_coef: 0.6735
# Epoch 7676/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6735 - val_accuracy: 0.9342 - val_IoU_coef: 0.6735
# Epoch 7677/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6739 - val_accuracy: 0.9341 - val_IoU_coef: 0.6739
# Epoch 7678/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8303 - accuracy: 0.9402 - IoU_coef: 0.8303 - val_loss: -0.6739 - val_accuracy: 0.9342 - val_IoU_coef: 0.6739
# Epoch 7679/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6735 - val_accuracy: 0.9343 - val_IoU_coef: 0.6735
# Epoch 7680/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8304 - accuracy: 0.9402 - IoU_coef: 0.8304 - val_loss: -0.6735 - val_accuracy: 0.9343 - val_IoU_coef: 0.6735
# Epoch 7681/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6736 - val_accuracy: 0.9342 - val_IoU_coef: 0.6736
# Epoch 7682/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8307 - accuracy: 0.9401 - IoU_coef: 0.8307 - val_loss: -0.6745 - val_accuracy: 0.9343 - val_IoU_coef: 0.6745
# Epoch 7683/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6746 - val_accuracy: 0.9344 - val_IoU_coef: 0.6746
# Epoch 7684/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6742 - val_accuracy: 0.9343 - val_IoU_coef: 0.6742
# Epoch 7685/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6735 - val_accuracy: 0.9342 - val_IoU_coef: 0.6735
# Epoch 7686/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6735 - val_accuracy: 0.9342 - val_IoU_coef: 0.6735
# Epoch 7687/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8306 - accuracy: 0.9402 - IoU_coef: 0.8306 - val_loss: -0.6741 - val_accuracy: 0.9343 - val_IoU_coef: 0.6741
# Epoch 7688/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6750 - val_accuracy: 0.9344 - val_IoU_coef: 0.6750
# Epoch 7689/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8308 - accuracy: 0.9402 - IoU_coef: 0.8308 - val_loss: -0.6746 - val_accuracy: 0.9344 - val_IoU_coef: 0.6746
# Epoch 7690/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6742 - val_accuracy: 0.9343 - val_IoU_coef: 0.6742
# Epoch 7691/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6743 - val_accuracy: 0.9344 - val_IoU_coef: 0.6743
# Epoch 7692/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6750 - val_accuracy: 0.9345 - val_IoU_coef: 0.6750
# Epoch 7693/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6756 - val_accuracy: 0.9346 - val_IoU_coef: 0.6756
# Epoch 7694/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6757 - val_accuracy: 0.9346 - val_IoU_coef: 0.6757
# Epoch 7695/10000
# 1/1 [==============================] - 0s 362ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6758 - val_accuracy: 0.9346 - val_IoU_coef: 0.6758
# Epoch 7696/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6762 - val_accuracy: 0.9346 - val_IoU_coef: 0.6762
# Epoch 7697/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6767 - val_accuracy: 0.9346 - val_IoU_coef: 0.6767
# Epoch 7698/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6763 - val_accuracy: 0.9345 - val_IoU_coef: 0.6763
# Epoch 7699/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6758 - val_accuracy: 0.9344 - val_IoU_coef: 0.6758
# Epoch 7700/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6759 - val_accuracy: 0.9343 - val_IoU_coef: 0.6759
# Epoch 7701/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6756 - val_accuracy: 0.9343 - val_IoU_coef: 0.6756
# Epoch 7702/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6752 - val_accuracy: 0.9343 - val_IoU_coef: 0.6752
# Epoch 7703/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6745 - val_accuracy: 0.9342 - val_IoU_coef: 0.6745
# Epoch 7704/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6742 - val_accuracy: 0.9342 - val_IoU_coef: 0.6742
# Epoch 7705/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6748 - val_accuracy: 0.9342 - val_IoU_coef: 0.6748
# Epoch 7706/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6752 - val_accuracy: 0.9343 - val_IoU_coef: 0.6752
# Epoch 7707/10000
# 1/1 [==============================] - 0s 353ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6751 - val_accuracy: 0.9343 - val_IoU_coef: 0.6751
# Epoch 7708/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6752 - val_accuracy: 0.9343 - val_IoU_coef: 0.6752
# Epoch 7709/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6759 - val_accuracy: 0.9345 - val_IoU_coef: 0.6759
# Epoch 7710/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6764 - val_accuracy: 0.9346 - val_IoU_coef: 0.6764
# Epoch 7711/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6766 - val_accuracy: 0.9346 - val_IoU_coef: 0.6766
# Epoch 7712/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6764 - val_accuracy: 0.9346 - val_IoU_coef: 0.6764
# Epoch 7713/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6757 - val_accuracy: 0.9346 - val_IoU_coef: 0.6757
# Epoch 7714/10000
# 1/1 [==============================] - 0s 337ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6755 - val_accuracy: 0.9346 - val_IoU_coef: 0.6755
# Epoch 7715/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6758 - val_accuracy: 0.9346 - val_IoU_coef: 0.6758
# Epoch 7716/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6759 - val_accuracy: 0.9346 - val_IoU_coef: 0.6759
# Epoch 7717/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6756 - val_accuracy: 0.9346 - val_IoU_coef: 0.6756
# Epoch 7718/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6750 - val_accuracy: 0.9345 - val_IoU_coef: 0.6750
# Epoch 7719/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6746 - val_accuracy: 0.9345 - val_IoU_coef: 0.6746
# Epoch 7720/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6746 - val_accuracy: 0.9345 - val_IoU_coef: 0.6746
# Epoch 7721/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6745 - val_accuracy: 0.9345 - val_IoU_coef: 0.6745
# Epoch 7722/10000
# 1/1 [==============================] - 0s 350ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6741 - val_accuracy: 0.9345 - val_IoU_coef: 0.6741
# Epoch 7723/10000
# 1/1 [==============================] - 0s 336ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6744 - val_accuracy: 0.9345 - val_IoU_coef: 0.6744
# Epoch 7724/10000
# 1/1 [==============================] - 0s 362ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6741 - val_accuracy: 0.9344 - val_IoU_coef: 0.6741
# Epoch 7725/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8309 - accuracy: 0.9402 - IoU_coef: 0.8309 - val_loss: -0.6741 - val_accuracy: 0.9344 - val_IoU_coef: 0.6741
# Epoch 7726/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8314 - accuracy: 0.9402 - IoU_coef: 0.8314 - val_loss: -0.6745 - val_accuracy: 0.9344 - val_IoU_coef: 0.6745
# Epoch 7727/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6750 - val_accuracy: 0.9344 - val_IoU_coef: 0.6750
# Epoch 7728/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6747 - val_accuracy: 0.9344 - val_IoU_coef: 0.6747
# Epoch 7729/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6738 - val_accuracy: 0.9342 - val_IoU_coef: 0.6738
# Epoch 7730/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6741 - val_accuracy: 0.9343 - val_IoU_coef: 0.6741
# Epoch 7731/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6751 - val_accuracy: 0.9344 - val_IoU_coef: 0.6751
# Epoch 7732/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6761 - val_accuracy: 0.9345 - val_IoU_coef: 0.6761
# Epoch 7733/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6756 - val_accuracy: 0.9345 - val_IoU_coef: 0.6756
# Epoch 7734/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6750 - val_accuracy: 0.9344 - val_IoU_coef: 0.6750
# Epoch 7735/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6746 - val_accuracy: 0.9343 - val_IoU_coef: 0.6746
# Epoch 7736/10000
# 1/1 [==============================] - 0s 337ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6740 - val_accuracy: 0.9342 - val_IoU_coef: 0.6740
# Epoch 7737/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6738 - val_accuracy: 0.9342 - val_IoU_coef: 0.6738
# Epoch 7738/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6735 - val_accuracy: 0.9341 - val_IoU_coef: 0.6735
# Epoch 7739/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6735 - val_accuracy: 0.9341 - val_IoU_coef: 0.6735
# Epoch 7740/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6737 - val_accuracy: 0.9342 - val_IoU_coef: 0.6737
# Epoch 7741/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6740 - val_accuracy: 0.9342 - val_IoU_coef: 0.6740
# Epoch 7742/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6735 - val_accuracy: 0.9342 - val_IoU_coef: 0.6735
# Epoch 7743/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8315 - accuracy: 0.9402 - IoU_coef: 0.8315 - val_loss: -0.6732 - val_accuracy: 0.9341 - val_IoU_coef: 0.6732
# Epoch 7744/10000
# 1/1 [==============================] - 0s 369ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6733 - val_accuracy: 0.9342 - val_IoU_coef: 0.6733
# Epoch 7745/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6744 - val_accuracy: 0.9343 - val_IoU_coef: 0.6744
# Epoch 7746/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8313 - accuracy: 0.9402 - IoU_coef: 0.8313 - val_loss: -0.6752 - val_accuracy: 0.9344 - val_IoU_coef: 0.6752
# Epoch 7747/10000
# 1/1 [==============================] - 0s 350ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6750 - val_accuracy: 0.9344 - val_IoU_coef: 0.6750
# Epoch 7748/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8312 - accuracy: 0.9402 - IoU_coef: 0.8312 - val_loss: -0.6747 - val_accuracy: 0.9344 - val_IoU_coef: 0.6747
# Epoch 7749/10000
# 1/1 [==============================] - 0s 349ms/step - loss: -0.8311 - accuracy: 0.9402 - IoU_coef: 0.8311 - val_loss: -0.6743 - val_accuracy: 0.9344 - val_IoU_coef: 0.6743
# Epoch 7750/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8314 - accuracy: 0.9402 - IoU_coef: 0.8314 - val_loss: -0.6740 - val_accuracy: 0.9344 - val_IoU_coef: 0.6740
# Epoch 7751/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8310 - accuracy: 0.9402 - IoU_coef: 0.8310 - val_loss: -0.6739 - val_accuracy: 0.9344 - val_IoU_coef: 0.6739
# Epoch 7752/10000
# ...
# Epoch 9917/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6749 - val_accuracy: 0.9344 - val_IoU_coef: 0.6749
# Epoch 9918/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6754 - val_accuracy: 0.9344 - val_IoU_coef: 0.6754
# Epoch 9919/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6747 - val_accuracy: 0.9343 - val_IoU_coef: 0.6747
# Epoch 9920/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6745 - val_accuracy: 0.9342 - val_IoU_coef: 0.6745
# Epoch 9921/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6752 - val_accuracy: 0.9343 - val_IoU_coef: 0.6752
# Epoch 9922/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6754 - val_accuracy: 0.9342 - val_IoU_coef: 0.6754
# Epoch 9923/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6761 - val_accuracy: 0.9343 - val_IoU_coef: 0.6761
# Epoch 9924/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6764 - val_accuracy: 0.9343 - val_IoU_coef: 0.6764
# Epoch 9925/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6769 - val_accuracy: 0.9344 - val_IoU_coef: 0.6769
# Epoch 9926/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6763 - val_accuracy: 0.9342 - val_IoU_coef: 0.6763
# Epoch 9927/10000
# 1/1 [==============================] - 0s 367ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6757 - val_accuracy: 0.9342 - val_IoU_coef: 0.6757
# Epoch 9928/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6753 - val_accuracy: 0.9342 - val_IoU_coef: 0.6753
# Epoch 9929/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6755 - val_accuracy: 0.9342 - val_IoU_coef: 0.6755
# Epoch 9930/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6761 - val_accuracy: 0.9343 - val_IoU_coef: 0.6761
# Epoch 9931/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6771 - val_accuracy: 0.9345 - val_IoU_coef: 0.6771
# Epoch 9932/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6778 - val_accuracy: 0.9346 - val_IoU_coef: 0.6778
# Epoch 9933/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8368 - accuracy: 0.9402 - IoU_coef: 0.8368 - val_loss: -0.6773 - val_accuracy: 0.9346 - val_IoU_coef: 0.6773
# Epoch 9934/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6768 - val_accuracy: 0.9345 - val_IoU_coef: 0.6768
# Epoch 9935/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6765 - val_accuracy: 0.9345 - val_IoU_coef: 0.6765
# Epoch 9936/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6765 - val_accuracy: 0.9346 - val_IoU_coef: 0.6765
# Epoch 9937/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6768 - val_accuracy: 0.9346 - val_IoU_coef: 0.6768
# Epoch 9938/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8369 - accuracy: 0.9402 - IoU_coef: 0.8369 - val_loss: -0.6765 - val_accuracy: 0.9346 - val_IoU_coef: 0.6765
# Epoch 9939/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6760 - val_accuracy: 0.9346 - val_IoU_coef: 0.6760
# Epoch 9940/10000
# 1/1 [==============================] - 0s 338ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6760 - val_accuracy: 0.9346 - val_IoU_coef: 0.6760
# Epoch 9941/10000
# 1/1 [==============================] - 0s 336ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6761 - val_accuracy: 0.9346 - val_IoU_coef: 0.6761
# Epoch 9942/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6764 - val_accuracy: 0.9346 - val_IoU_coef: 0.6764
# Epoch 9943/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6768 - val_accuracy: 0.9346 - val_IoU_coef: 0.6768
# Epoch 9944/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6769 - val_accuracy: 0.9347 - val_IoU_coef: 0.6769
# Epoch 9945/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6772 - val_accuracy: 0.9347 - val_IoU_coef: 0.6772
# Epoch 9946/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6775 - val_accuracy: 0.9347 - val_IoU_coef: 0.6775
# Epoch 9947/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6779 - val_accuracy: 0.9347 - val_IoU_coef: 0.6779
# Epoch 9948/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8368 - accuracy: 0.9402 - IoU_coef: 0.8368 - val_loss: -0.6779 - val_accuracy: 0.9347 - val_IoU_coef: 0.6779
# Epoch 9949/10000
# 1/1 [==============================] - 0s 337ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6774 - val_accuracy: 0.9347 - val_IoU_coef: 0.6774
# Epoch 9950/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6766 - val_accuracy: 0.9346 - val_IoU_coef: 0.6766
# Epoch 9951/10000
# 1/1 [==============================] - 0s 349ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6763 - val_accuracy: 0.9346 - val_IoU_coef: 0.6763
# Epoch 9952/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6758 - val_accuracy: 0.9345 - val_IoU_coef: 0.6758
# Epoch 9953/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6748 - val_accuracy: 0.9344 - val_IoU_coef: 0.6748
# Epoch 9954/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6740 - val_accuracy: 0.9343 - val_IoU_coef: 0.6740
# Epoch 9955/10000
# 1/1 [==============================] - 0s 338ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6737 - val_accuracy: 0.9343 - val_IoU_coef: 0.6737
# Epoch 9956/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6736 - val_accuracy: 0.9342 - val_IoU_coef: 0.6736
# Epoch 9957/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6732 - val_accuracy: 0.9342 - val_IoU_coef: 0.6732
# Epoch 9958/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6732 - val_accuracy: 0.9342 - val_IoU_coef: 0.6732
# Epoch 9959/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6730 - val_accuracy: 0.9342 - val_IoU_coef: 0.6730
# Epoch 9960/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6735 - val_accuracy: 0.9343 - val_IoU_coef: 0.6735
# Epoch 9961/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6741 - val_accuracy: 0.9344 - val_IoU_coef: 0.6741
# Epoch 9962/10000
# 1/1 [==============================] - 0s 348ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6745 - val_accuracy: 0.9345 - val_IoU_coef: 0.6745
# Epoch 9963/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6750 - val_accuracy: 0.9346 - val_IoU_coef: 0.6750
# Epoch 9964/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8369 - accuracy: 0.9402 - IoU_coef: 0.8369 - val_loss: -0.6758 - val_accuracy: 0.9346 - val_IoU_coef: 0.6758
# Epoch 9965/10000
# 1/1 [==============================] - 0s 346ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6756 - val_accuracy: 0.9346 - val_IoU_coef: 0.6756
# Epoch 9966/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6759 - val_accuracy: 0.9346 - val_IoU_coef: 0.6759
# Epoch 9967/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6761 - val_accuracy: 0.9347 - val_IoU_coef: 0.6761
# Epoch 9968/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6767 - val_accuracy: 0.9346 - val_IoU_coef: 0.6767
# Epoch 9969/10000
# 1/1 [==============================] - 0s 355ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6768 - val_accuracy: 0.9346 - val_IoU_coef: 0.6768
# Epoch 9970/10000
# 1/1 [==============================] - 0s 338ms/step - loss: -0.8369 - accuracy: 0.9402 - IoU_coef: 0.8369 - val_loss: -0.6765 - val_accuracy: 0.9346 - val_IoU_coef: 0.6765
# Epoch 9971/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6757 - val_accuracy: 0.9346 - val_IoU_coef: 0.6757
# Epoch 9972/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6752 - val_accuracy: 0.9345 - val_IoU_coef: 0.6752
# Epoch 9973/10000
# 1/1 [==============================] - 0s 339ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6746 - val_accuracy: 0.9344 - val_IoU_coef: 0.6746
# Epoch 9974/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6742 - val_accuracy: 0.9343 - val_IoU_coef: 0.6742
# Epoch 9975/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6742 - val_accuracy: 0.9344 - val_IoU_coef: 0.6742
# Epoch 9976/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6744 - val_accuracy: 0.9344 - val_IoU_coef: 0.6744
# Epoch 9977/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6745 - val_accuracy: 0.9343 - val_IoU_coef: 0.6745
# Epoch 9978/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6739 - val_accuracy: 0.9342 - val_IoU_coef: 0.6739
# Epoch 9979/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6741 - val_accuracy: 0.9342 - val_IoU_coef: 0.6741
# Epoch 9980/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6747 - val_accuracy: 0.9343 - val_IoU_coef: 0.6747
# Epoch 9981/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8375 - accuracy: 0.9402 - IoU_coef: 0.8375 - val_loss: -0.6752 - val_accuracy: 0.9344 - val_IoU_coef: 0.6752
# Epoch 9982/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6755 - val_accuracy: 0.9344 - val_IoU_coef: 0.6755
# Epoch 9983/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6756 - val_accuracy: 0.9344 - val_IoU_coef: 0.6756
# Epoch 9984/10000
# 1/1 [==============================] - 0s 351ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6763 - val_accuracy: 0.9345 - val_IoU_coef: 0.6763
# Epoch 9985/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6761 - val_accuracy: 0.9345 - val_IoU_coef: 0.6761
# Epoch 9986/10000
# 1/1 [==============================] - 0s 343ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6757 - val_accuracy: 0.9345 - val_IoU_coef: 0.6757
# Epoch 9987/10000
# 1/1 [==============================] - 0s 337ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6760 - val_accuracy: 0.9345 - val_IoU_coef: 0.6760
# Epoch 9988/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6763 - val_accuracy: 0.9345 - val_IoU_coef: 0.6763
# Epoch 9989/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6765 - val_accuracy: 0.9345 - val_IoU_coef: 0.6765
# Epoch 9990/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6765 - val_accuracy: 0.9345 - val_IoU_coef: 0.6765
# Epoch 9991/10000
# 1/1 [==============================] - 0s 345ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6764 - val_accuracy: 0.9344 - val_IoU_coef: 0.6764
# Epoch 9992/10000
# 1/1 [==============================] - 0s 340ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6766 - val_accuracy: 0.9344 - val_IoU_coef: 0.6766
# Epoch 9993/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6762 - val_accuracy: 0.9343 - val_IoU_coef: 0.6762
# Epoch 9994/10000
# 1/1 [==============================] - 0s 344ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6748 - val_accuracy: 0.9341 - val_IoU_coef: 0.6748
# Epoch 9995/10000
# 1/1 [==============================] - 0s 347ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6741 - val_accuracy: 0.9340 - val_IoU_coef: 0.6741
# Epoch 9996/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8373 - accuracy: 0.9402 - IoU_coef: 0.8373 - val_loss: -0.6744 - val_accuracy: 0.9340 - val_IoU_coef: 0.6744
# Epoch 9997/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8374 - accuracy: 0.9402 - IoU_coef: 0.8374 - val_loss: -0.6750 - val_accuracy: 0.9340 - val_IoU_coef: 0.6750
# Epoch 9998/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8371 - accuracy: 0.9402 - IoU_coef: 0.8371 - val_loss: -0.6754 - val_accuracy: 0.9340 - val_IoU_coef: 0.6754
# Epoch 9999/10000
# 1/1 [==============================] - 0s 342ms/step - loss: -0.8370 - accuracy: 0.9402 - IoU_coef: 0.8370 - val_loss: -0.6751 - val_accuracy: 0.9340 - val_IoU_coef: 0.6751
# Epoch 10000/10000
# 1/1 [==============================] - 0s 341ms/step - loss: -0.8372 - accuracy: 0.9402 - IoU_coef: 0.8372 - val_loss: -0.6752 - val_accuracy: 0.9341 - val_IoU_coef: 0.6752

# %% [markdown]
# <h1><center>Save The Trained Model</center></h1>

# %%
#save model
model.save('drive/MyDrive/Datasets/STARE/retina_Unet_epochs_10000_STARE.hdf5')

# %% [markdown]
# <h3><center>Plot Info About The Trained Model</center></h3>

# %%
#training-validation loss curve
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(7,5))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

#training-validation accuracy curve
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(7,5))
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'y', label='Validation Accuracy')
plt.title('Training and validation accuracies')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#training-validation IoU curve
iou_coef = history.history['IoU_coef']
val_iou_coef = history.history['val_IoU_coef']
plt.figure(figsize=(7,5))
plt.plot(epochs, iou_coef, 'r', label='Training IoU')
plt.plot(epochs, val_iou_coef, 'y', label='Validation IoU')
plt.title('Training and validation IoU coefficients')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

# %% [markdown]
# <h1><center>Load Trained Model To Make Prediction On Test Data</center></h1>

# %%
# CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized

patch_size = 512

#loading model architectures
from tensorflow.keras.optimizers import Adam


IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

model = unetmodel(input_shape) 
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model.load_weights('drive/MyDrive/Datasets/STARE/retina_Unet_epochs_10000_STARE.hdf5') #loading weights


path1 = 'drive/MyDrive/Datasets/STARE/Testing/Images'    #test dataset images directory path
path2 = 'drive/MyDrive/Datasets/STARE/Testing/Labels'     #test dataset mask directory path


from sklearn.metrics import jaccard_score,confusion_matrix

testimg = []
ground_truth = []
prediction = []
global_IoU = []
global_accuracy = []

testimages = sorted(os.listdir(path1))
testmasks =  sorted(os.listdir(path2))

for idx, image_name in enumerate(testimages):  
   if image_name.endswith(tuple(myList)):  
      predicted_patches = []
      test_img = skimage.io.imread(path1+"/"+image_name)
     
      test = test_img[:,:,1] #selecting green channel
      test = clahe_equalized(test) #applying CLAHE
      SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
      SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
      test = cv2.resize(test, (SIZE_X, SIZE_Y))
      testimg.append(test)           
      test = np.array(test)

      patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

      for i in range(patches.shape[0]):
                for j in range(patches.shape[1]):
                  single_patch = patches[i,j,:,:]
                  single_patch_norm = (single_patch.astype('float32')) / 255.
                  single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
                  single_patch_input = np.expand_dims(single_patch_norm, 0)
                  single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
                  predicted_patches.append(single_patch_prediction)
      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img
      prediction.append(reconstructed_image) 

      groundtruth=[]
      groundtruth = skimage.io.imread(path2+'/'+testmasks[idx]) #reading mask of the test img      
      SIZE_X = (groundtruth.shape[1]//patch_size)*patch_size 
      SIZE_Y = (groundtruth.shape[0]//patch_size)*patch_size  
      groundtruth = cv2.resize(groundtruth, (SIZE_X, SIZE_Y))  
      ground_truth.append(groundtruth)

      y_true = groundtruth
      y_pred = reconstructed_image
      labels = [0, 1]
      IoU = []
      for label in labels:
          jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
          IoU.append(jaccard)
      IoU = np.mean(IoU) #jacard/IoU of single image
      global_IoU.append(IoU)

      cm=[]
      accuracy = []
      cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
      accuracy = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1]) #accuracy of single image
      global_accuracy.append(accuracy)


avg_acc =  np.mean(global_accuracy)
mean_IoU = np.mean(global_IoU)

print('Average accuracy is',avg_acc)
print('mean IoU is',mean_IoU)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1321: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)
# Average accuracy is 0.9910745094890796
# mean IoU is 0.8790894493889083

# %% [markdown]
# <h1><center>Visualise The Segmentation Result</center></h1>

# %%
#checking segmentation results
import random
test_img_number = random.randint(0, len(testimg))
plt.figure(figsize=(20, 18))
plt.subplot(231)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(testimg[test_img_number])
plt.subplot(232)
plt.title('Ground Truth')
plt.xticks([])
plt.yticks([])
plt.imshow(ground_truth[test_img_number],cmap='gray')
plt.subplot(233)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(prediction[test_img_number],cmap='gray')

plt.show()

# %% [markdown]
# <h1><center>Visualise Segmentation On A Particular Image</center></h1>

# %%
#prediction on single image
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('drive/MyDrive/Datasets/STARE/Testing/Images/im0004.ppm') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# Execution time:  0:00:00.046004
